# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinash730/sp/blob/main/Stock_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('/content/GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
# <ipython-input-5-3d1443e590ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 7s 86ms/step - loss: 0.0099 - mean_absolute_error: 0.0691 - val_loss: 0.0192 - val_mean_absolute_error: 0.1214
# Epoch 2/80
# 30/30 [==============================] - 3s 90ms/step - loss: 9.8809e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0038 - val_mean_absolute_error: 0.0504
# Epoch 3/80
# 30/30 [==============================] - 2s 54ms/step - loss: 5.7417e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0018 - val_mean_absolute_error: 0.0349
# Epoch 4/80
# 30/30 [==============================] - 2s 51ms/step - loss: 5.3854e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 5/80
# 30/30 [==============================] - 2s 51ms/step - loss: 5.1316e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0034 - val_mean_absolute_error: 0.0466
# Epoch 6/80
# 30/30 [==============================] - 2s 51ms/step - loss: 5.1159e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 7/80
# 30/30 [==============================] - 2s 51ms/step - loss: 4.5290e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0035 - val_mean_absolute_error: 0.0477
# Epoch 8/80
# 30/30 [==============================] - 2s 52ms/step - loss: 4.6030e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0043 - val_mean_absolute_error: 0.0545
# Epoch 9/80
# 30/30 [==============================] - 2s 79ms/step - loss: 3.9847e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0032 - val_mean_absolute_error: 0.0459
# Epoch 10/80
# 30/30 [==============================] - 2s 65ms/step - loss: 3.7615e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0065 - val_mean_absolute_error: 0.0700
# Epoch 11/80
# 30/30 [==============================] - 2s 52ms/step - loss: 4.1802e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0079 - val_mean_absolute_error: 0.0777
# Epoch 12/80
# 30/30 [==============================] - 2s 53ms/step - loss: 3.9392e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0034 - val_mean_absolute_error: 0.0473
# Epoch 13/80
# 30/30 [==============================] - 2s 56ms/step - loss: 4.1431e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0049 - val_mean_absolute_error: 0.0580
# Epoch 14/80
# 30/30 [==============================] - 2s 53ms/step - loss: 3.5215e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0070 - val_mean_absolute_error: 0.0714
# Epoch 15/80
# 30/30 [==============================] - 2s 52ms/step - loss: 3.4197e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0056 - val_mean_absolute_error: 0.0623
# Epoch 16/80
# 30/30 [==============================] - 2s 67ms/step - loss: 3.4186e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0060 - val_mean_absolute_error: 0.0646
# Epoch 17/80
# 30/30 [==============================] - 2s 76ms/step - loss: 3.3223e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0090 - val_mean_absolute_error: 0.0818
# Epoch 18/80
# 30/30 [==============================] - 2s 52ms/step - loss: 3.2624e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0069 - val_mean_absolute_error: 0.0701
# Epoch 19/80
# 30/30 [==============================] - 2s 51ms/step - loss: 3.5545e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0071 - val_mean_absolute_error: 0.0711
# Epoch 20/80
# 30/30 [==============================] - 2s 54ms/step - loss: 3.2211e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0069 - val_mean_absolute_error: 0.0686
# Epoch 21/80
# 30/30 [==============================] - 2s 53ms/step - loss: 3.0724e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0044 - val_mean_absolute_error: 0.0523
# Epoch 22/80
# 30/30 [==============================] - 2s 52ms/step - loss: 3.1201e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0082 - val_mean_absolute_error: 0.0762
# Epoch 23/80
# 30/30 [==============================] - 2s 54ms/step - loss: 3.0845e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0077 - val_mean_absolute_error: 0.0732
# Epoch 24/80
# 30/30 [==============================] - 3s 87ms/step - loss: 2.9369e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0087 - val_mean_absolute_error: 0.0796
# Epoch 25/80
# 30/30 [==============================] - 2s 51ms/step - loss: 3.1291e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0088 - val_mean_absolute_error: 0.0793
# Epoch 26/80
# 30/30 [==============================] - 2s 52ms/step - loss: 3.1956e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0067 - val_mean_absolute_error: 0.0674
# Epoch 27/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.9073e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0049 - val_mean_absolute_error: 0.0548
# Epoch 28/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.9264e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 29/80
# 30/30 [==============================] - 2s 54ms/step - loss: 2.7306e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0028 - val_mean_absolute_error: 0.0399
# Epoch 30/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.6770e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0060 - val_mean_absolute_error: 0.0627
# Epoch 31/80
# 30/30 [==============================] - 2s 77ms/step - loss: 2.5429e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0054 - val_mean_absolute_error: 0.0594
# Epoch 32/80
# 30/30 [==============================] - 2s 66ms/step - loss: 2.5522e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0053 - val_mean_absolute_error: 0.0571
# Epoch 33/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.5538e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0050 - val_mean_absolute_error: 0.0563
# Epoch 34/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.5447e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0040 - val_mean_absolute_error: 0.0481
# Epoch 35/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.3690e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0050 - val_mean_absolute_error: 0.0546
# Epoch 36/80
# 30/30 [==============================] - 2s 80ms/step - loss: 2.5198e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0082 - val_mean_absolute_error: 0.0767
# Epoch 37/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.4992e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0059 - val_mean_absolute_error: 0.0615
# Epoch 38/80
# 30/30 [==============================] - 2s 83ms/step - loss: 2.3874e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0055 - val_mean_absolute_error: 0.0583
# Epoch 39/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.3955e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0044 - val_mean_absolute_error: 0.0522
# Epoch 40/80
# 30/30 [==============================] - 2s 54ms/step - loss: 2.4221e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0049 - val_mean_absolute_error: 0.0586
# Epoch 41/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.2564e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0043 - val_mean_absolute_error: 0.0531
# Epoch 42/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.3110e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0031 - val_mean_absolute_error: 0.0430
# Epoch 43/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.0471e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0028 - val_mean_absolute_error: 0.0408
# Epoch 44/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.1164e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0042 - val_mean_absolute_error: 0.0528
# Epoch 45/80
# 30/30 [==============================] - 2s 66ms/step - loss: 2.2621e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0047 - val_mean_absolute_error: 0.0547
# Epoch 46/80
# 30/30 [==============================] - 2s 74ms/step - loss: 2.2236e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0026 - val_mean_absolute_error: 0.0388
# Epoch 47/80
# 30/30 [==============================] - 2s 53ms/step - loss: 2.1500e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0051 - val_mean_absolute_error: 0.0582
# Epoch 48/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.9814e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0042 - val_mean_absolute_error: 0.0525
# Epoch 49/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.9214e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0052 - val_mean_absolute_error: 0.0606
# Epoch 50/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.9238e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0035 - val_mean_absolute_error: 0.0480
# Epoch 51/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.8325e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0029 - val_mean_absolute_error: 0.0435
# Epoch 52/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.8123e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 53/80
# 30/30 [==============================] - 3s 87ms/step - loss: 1.9146e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0056 - val_mean_absolute_error: 0.0636
# Epoch 54/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.8262e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0046 - val_mean_absolute_error: 0.0567
# Epoch 55/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.8354e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352
# Epoch 56/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7118e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 57/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.7207e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0026 - val_mean_absolute_error: 0.0411
# Epoch 58/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7299e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0031 - val_mean_absolute_error: 0.0447
# Epoch 59/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.6997e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0026 - val_mean_absolute_error: 0.0405
# Epoch 60/80
# 30/30 [==============================] - 2s 84ms/step - loss: 1.5939e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0034 - val_mean_absolute_error: 0.0486
# Epoch 61/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.6154e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0018 - val_mean_absolute_error: 0.0334
# Epoch 62/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7265e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0032 - val_mean_absolute_error: 0.0456
# Epoch 63/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7468e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0073 - val_mean_absolute_error: 0.0749
# Epoch 64/80
# 30/30 [==============================] - 2s 56ms/step - loss: 1.7312e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0029 - val_mean_absolute_error: 0.0438
# Epoch 65/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.6193e-04 - mean_absolute_error: 0.0094 - val_loss: 9.9430e-04 - val_mean_absolute_error: 0.0239
# Epoch 66/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.5281e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0030 - val_mean_absolute_error: 0.0448
# Epoch 67/80
# 30/30 [==============================] - 2s 71ms/step - loss: 1.5658e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0028 - val_mean_absolute_error: 0.0429
# Epoch 68/80
# 30/30 [==============================] - 2s 72ms/step - loss: 1.5052e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0026 - val_mean_absolute_error: 0.0414
# Epoch 69/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.5138e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0030 - val_mean_absolute_error: 0.0451
# Epoch 70/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.3832e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0025 - val_mean_absolute_error: 0.0410
# Epoch 71/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.5140e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0024 - val_mean_absolute_error: 0.0399
# Epoch 72/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.5117e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0022 - val_mean_absolute_error: 0.0382
# Epoch 73/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.4681e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0034 - val_mean_absolute_error: 0.0495
# Epoch 74/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.5326e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0014 - val_mean_absolute_error: 0.0286
# Epoch 75/80
# 30/30 [==============================] - 2s 80ms/step - loss: 1.4708e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0018 - val_mean_absolute_error: 0.0337
# Epoch 76/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.3275e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0025 - val_mean_absolute_error: 0.0411
# Epoch 77/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.5318e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 78/80
# 30/30 [==============================] - 2s 53ms/step - loss: 1.3572e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0018 - val_mean_absolute_error: 0.0345
# Epoch 79/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.5469e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 80/80
# 30/30 [==============================] - 2s 54ms/step - loss: 1.3002e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0015 - val_mean_absolute_error: 0.0295

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 15ms/step
# array([[0.4913883 , 0.4897001 ],
#        [0.49700558, 0.4948401 ],
#        [0.50287366, 0.50026584],
#        [0.51888293, 0.51617116],
#        [0.52846193, 0.5255258 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1581.9945, 1575.8408],
#        [1592.4086, 1585.367 ],
#        [1603.2876, 1595.4227],
#        [1632.9674, 1624.9008],
#        [1650.7262, 1642.238 ]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1581.994507      1575.840820
# 2020-08-25  1582.07  1608.22     1592.408569      1585.366943
# 2020-08-26  1608.00  1652.38     1603.287598      1595.422729
# 2020-08-27  1653.68  1634.33     1632.967407      1624.900757
# 2020-08-28  1633.49  1644.41     1650.726196      1642.238037

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# Out:
# <ipython-input-25-3796df6ba6f4>:3: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# <ipython-input-25-3796df6ba6f4>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2422.193115      2391.199707
# 2021-06-10  2494.01  2521.60     2435.505859      2400.386963
# 2021-06-11  2524.92  2513.93     2451.531494      2412.058105
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
